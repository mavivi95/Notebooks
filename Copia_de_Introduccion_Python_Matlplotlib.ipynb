# %% [markdown]
# <a href="https://colab.research.google.com/github/mavivi95/Notebooks/blob/main/Copia_de_Introduccion_Python_Matlplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
x = np.linspace(0, 2*math.pi, 30)
x
# Out:
# array([0.        , 0.21666156, 0.43332312, 0.64998469, 0.86664625,
#        1.08330781, 1.29996937, 1.51663094, 1.7332925 , 1.94995406,
#        2.16661562, 2.38327719, 2.59993875, 2.81660031, 3.03326187,
#        3.24992343, 3.466585  , 3.68324656, 3.89990812, 4.11656968,
#        4.33323125, 4.54989281, 4.76655437, 4.98321593, 5.1998775 ,
#        5.41653906, 5.63320062, 5.84986218, 6.06652374, 6.28318531])

# %%
y = np.sin(x)
y
# Out:
# array([ 0.00000000e+00,  2.14970440e-01,  4.19889102e-01,  6.05174215e-01,
#         7.62162055e-01,  8.83512044e-01,  9.63549993e-01,  9.98533414e-01,
#         9.86826523e-01,  9.28976720e-01,  8.27688998e-01,  6.87699459e-01,
#         5.15553857e-01,  3.19301530e-01,  1.08119018e-01, -1.08119018e-01,
#        -3.19301530e-01, -5.15553857e-01, -6.87699459e-01, -8.27688998e-01,
#        -9.28976720e-01, -9.86826523e-01, -9.98533414e-01, -9.63549993e-01,
#        -8.83512044e-01, -7.62162055e-01, -6.05174215e-01, -4.19889102e-01,
#        -2.14970440e-01, -2.44929360e-16])

# %%
plt.plot(x,y)
plt.show()

# %%
x = np.linspace(0, 2*math.pi, 50)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.title('Funciones seno y coseno')
plt.show()

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.title('Funciones seno y coseno')
plt.grid()

# %%
plt.plot(x,y1,'g')
plt.plot(x,y2,'r*')
plt.title('Funciones seno y coseno')
plt.grid()

# %%
plt.plot(x,y1,'m*')
plt.plot(x,y2,'b+')
plt.title('Funciones seno y coseno')
plt.grid()

# %%
plt.plot(x,y1,'g-', linewidth=4)
plt.plot(x,y2,'ro--')
plt.title('Funciones seno y coseno')
plt.grid()

# %%
plt.plot(x,y1,'b', linewidth=5)
plt.plot(x,y2,'m', linewidth=2)
plt.title('Funciones seno y coseno')
plt.grid()

# %%
plt.plot(x,y1, color='#D58959', linewidth=3, label='seno(x)')
plt.plot(x,y2, color='#76D7C4', linewidth=3, label='cos(x)')
plt.title('Funciones seno y coseno')
plt.grid()

# %%
plt.plot(x,y1, color='#A976D7', linewidth=3, label='seno(x)')
plt.plot(x,y2, color='#76D7C4', linewidth=3, label='cos(x)')
plt.legend()
plt.title('Funciones seno y coseno')
plt.grid()

# %%
plt.plot(x,y1, color='#A976D7', linewidth=3, label='seno(x)')
plt.plot(x,y2, color='#76D7C4', linewidth=3, label='cos(x)')
plt.legend(loc ='upper left')
plt.title('Funciones seno y coseno')
plt.grid()

# %%
plt.plot(x,y1, color='#A976D7', linewidth=3, label='seno(x)')
plt.plot(x,y2, color='#76D7C4', linewidth=3, label='cos(x)')
plt.legend(loc ='upper left')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Funciones seno y coseno')
plt.grid()

# %%
plt.plot(x,y1, color='#A976D7', linewidth=3, label='seno(x)')
plt.plot(x,y2, color='#76D7C4', linewidth=3, label='cos(x)')
plt.legend(loc ='best', fontsize=14)
plt.xlabel(r'$x$', fontsize=18)
plt.ylabel(r'$f(x)$', fontsize=18)
plt.title('Funciones seno y coseno', fontsize=20)
plt.grid()

# %% [markdown]
# ## Diagrama barras

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
materias = ['Matemáticas', 'Lectura', 'Ingles', 'Biologia', 'Sociales']
nota = []
for materia in materias:
  x = float(input(f'Ingrese la nota en {materia}:'))
  nota.append(x)
# Out:
# Ingrese la nota en Matemáticas:5
# Ingrese la nota en Lectura:4
# Ingrese la nota en Ingles:2
# Ingrese la nota en Biologia:5
# Ingrese la nota en Sociales:5

# %%
plt.bar(materias, nota)
plt.show()

# %%
plt.bar(materias, nota)
plt.title('Gráficas notas por materia', fontsize=16)
plt.ylabel('Nota')
plt.show()

# %%
plt.bar(materias, nota)
plt.axhline(y=3, color='r')
plt.title('Gráficas notas por materia', fontsize=16)
plt.ylabel('Nota')
# Out:
# Text(0, 0.5, 'Nota')

# %%
colores = ['#A976D7', '#76CBD7', '#80D776', '#D776B4', '#D7B776']
i = 0
for materia in materias:
  plt.bar(materia, nota[i], color=colores[i])
  i +=1
plt.axhline(y=3, color='r', lw=2)
plt.title('Gráficas notas por materia', fontsize=16)
plt.ylabel('Nota', fontsize=16)
plt.xlabel('Materias', fontsize=16)
# Out:
# Text(0.5, 0, 'Materias')

# %% [markdown]
# ## Barras dobles

# %%
materias = ['Matemáticas', 'Lectura', 'Ingles', 'Biologia', 'Sociales']
nota = []
nota2 = []
for materia in materias:
  x = float(input(f'Ingrese la promedio del salon 7-2 en {materia}:'))
  nota.append(x)
  x = float(input(f'Ingrese la promedio del salon 7-3 en {materia}:'))
  nota2.append(x)
# Out:
# Ingrese la promedio del salon 7-2 en Matemáticas:4
# Ingrese la promedio del salon 7-3 en Matemáticas:3
# Ingrese la promedio del salon 7-2 en Lectura:5
# Ingrese la promedio del salon 7-3 en Lectura:2
# Ingrese la promedio del salon 7-2 en Ingles:4.5
# Ingrese la promedio del salon 7-3 en Ingles:3
# Ingrese la promedio del salon 7-2 en Biologia:2
# Ingrese la promedio del salon 7-3 en Biologia:5
# Ingrese la promedio del salon 7-2 en Sociales:2.5
# Ingrese la promedio del salon 7-3 en Sociales:3

# %%
indice_barras = np.arange(len(nota))
indice_barras
# Out:
# array([0, 1, 2, 3, 4])

# %%
indice_barras + 0.25
# Out:
# array([0.25, 1.25, 2.25, 3.25, 4.25])

# %%
width_bar = 0.25
 
plt.bar(indice_barras, nota, width=width_bar, label='Salon 7-2', color='#549EB5')
plt.bar(indice_barras + width_bar, nota2, width=width_bar, label='Salon 7-3', color='#B56B54')
plt.legend(loc='best')

plt.xticks(indice_barras + width_bar, materias)
 
plt.ylabel('Nota')
plt.title('Promedio de notas por curso')
 
plt.axhline(y=3.5, color='r', lw=2)
plt.show()

# %% [markdown]
# ## Barras horizontales

# %%
departamento = ['Putumayo', 'Nariño', 'Cauca', 'Huila', 'Valle']
cobertura_electrica = [10, 25, 45, 65, 89]
plt.barh(departamento, cobertura_electrica, align='center', alpha=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
departamento = ['Putumayo', 'Nariño', 'Cauca', 'Huila', 'Valle']
cobertura_electrica = [10, 25, 45, 65, 89]
plt.barh(departamento, cobertura_electrica, align='center', alpha=0.8, color='#1B4F72')
plt.title('Cobertura eléctrica', fontsize = 14)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.axvline(x=20, color='r')
plt.show()

# %%
departamento = ['Putumayo', 'Nariño', 'Cauca', 'Huila', 'Valle']
cobertura_electrica = [10, 25, 45, 65, 89]
colores = ['#D6EAF8', '#5DADE2', '#2E86C1', '#2874A6', '#1B4F72']
i=0
for col in colores:
  plt.barh(departamento[i], cobertura_electrica[i], align='center', color=col, alpha = 0.5)
  i += 1


plt.title('Cobertura eléctrica', fontsize = 14)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.axvline(x=20, color='#F1C40F')
plt.show()

# %%
departamento = ['Putumayo', 'Nariño', 'Cauca', 'Huila', 'Valle']
cobertura_electrica = [10, 25, 45, 65, 89]
colores = ['#D6EAF8', '#5DADE2', '#2E86C1', '#2874A6', '#1B4F72']
i=0
for col in colores:
  plt.barh(departamento[i], cobertura_electrica[i], align='center', color=col, alpha = 0.5)
  i += 1


plt.title('Cobertura eléctrica', fontsize = 14)
plt.xlabel('%')
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
plt.axvline(x=20, color='#F1C40F')
plt.show()

# %% [markdown]
# ## Gráficos de puntos

# %%
# Generar números aleatorios entre 0 y 1 

x = 0.9 * np.random.rand(50)
y = 0.9 * np.random.rand(50)

plt.scatter(x, y)
plt.show()

# %%
x = 0.9 * np.random.rand(50)
y = 0.9 * np.random.rand(50)

plt.scatter(x, y, marker='^')

# %%
x = 0.9 * np.random.rand(50)
y = 0.9 * np.random.rand(50)

plt.scatter(x, y, marker='*')

# %%
x = 0.9 * np.random.rand(50)
y = 0.9 * np.random.rand(50)

plt.scatter(x, y, marker='*',s = 150)

# %%
x = 0.9 * np.random.rand(50)
y = 0.9 * np.random.rand(50)

plt.scatter(x, y, marker='^',s = 200)

# %%
x = 0.9 * np.random.rand(50)
y = 0.9 * np.random.rand(50)

plt.scatter(x, y, marker='*',s = 150, c = 'r')
plt.title('Datos')
plt.show()

# %%
x = 0.9 * np.random.rand(50)
y = 0.9 * np.random.rand(50)
k = 0
for i in x:
  if i < 0.4:
    plt.scatter(x[k], y[k], marker='^',s = 140, c = 'r')
  else:
    plt.scatter(x[k], y[k], marker='o',s = 140, c = 'b')
  k+=1


plt.title('Datos')
plt.show()

# %%
x = 0.9 * np.random.rand(50)
y = 0.9 * np.random.rand(50)
k = 0
for i in x:
  if i < 0.4:
    if y[k]<0.6:
      plt.scatter(x[k], y[k], marker='^',s = 140, c = '#18D53D')
    else:
      plt.scatter(x[k], y[k], marker='^',s = 80, c = '#18D5CF')
  else:
    if y[k]<0.6:
      plt.scatter(x[k], y[k], marker='o',s = 90, c = '#D518CC')
    else:
      plt.scatter(x[k], y[k], marker='*',s = 180, c = '#D51868')
  k+=1


plt.title('Datos')
plt.show()
